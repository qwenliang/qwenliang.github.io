# %% [markdown]
# ### Step 1: Connect to WRDS

# %%
#!pip install wrds
import wrds
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
###################
# Connect to WRDS #
###################
conn=wrds.Connection()
# Out:
# WRDS recommends setting up a .pgpass file.
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
conn = wrds.Connection(wrds_username='liangqingwen')
# Out:
# Loading library list...
# Done

# %%
conn.describe_table(library='crsp', table='msf')
# Out:
# Approximately 5037353 rows in crsp.msf.
#         name  nullable              type  \
# 0      cusip      True        VARCHAR(8)
# 1     permno      True           INTEGER
# 2     permco      True           INTEGER
# 3     issuno      True           INTEGER
# 4      hexcd      True          SMALLINT
# 5     hsiccd      True           INTEGER
# 6       date      True              DATE
# 7      bidlo      True    NUMERIC(11, 5)
# 8      askhi      True    NUMERIC(11, 5)
# 9        prc      True    NUMERIC(11, 5)
# 10       vol      True    NUMERIC(10, 0)
# 11       ret      True    NUMERIC(10, 6)
# 12       bid      True    NUMERIC(11, 5)
# 13       ask      True    NUMERIC(11, 5)
# 14    shrout      True  DOUBLE PRECISION
# 15    cfacpr      True  DOUBLE PRECISION
# 16   cfacshr      True  DOUBLE PRECISION
# 17    altprc      True    NUMERIC(11, 5)
# 18    spread      True    NUMERIC(10, 5)
# 19  altprcdt      True              DATE
# 20      retx      True    NUMERIC(10, 6)
#
#                                     comment
# 0                              CUSIP Header
# 1                                    PERMNO
# 2                                    PERMCO
# 3                       Nasdaq Issue Number
# 4                      Exchange Code Header
# 5   Standard Industrial Classification Code
# 6                       Date of Observation
# 7                          Bid or Low Price
# 8                         Ask or High Price
# 9                  Price or Bid/Ask Average
# 10                                   Volume
# 11                                  Returns
# 12                                      Bid
# 13                                      Ask
# 14                       Shares Outstanding
# 15       Cumulative Factor to Adjust Prices
# 16   Cumulative Factor to Adjust Shares/Vol
# 17                          Price Alternate
# 18               Spread Between Bid and Ask
# 19                     Alternate Price Date
# 20                Returns without Dividends

# %% [markdown]
# ### Step 2: Get SP500 Index Membership from CRSP
# - I opt for the monthly frequency of the data, but one can choose to work with crsp.dsp500list if more precise date range is needed.

# %%
# this list starts from 1/1/2008
sp500 = conn.raw_sql("""
                        select a.*, b.date, b.ret, b.vol, b.prc, b.spread,
                        b.shrout, b.retx, b.bidlo, b.askhi
                        from crsp.msp500list as a,
                        crsp.msf as b
                        where a.permno=b.permno
                        and b.date >= a.start and b.date<= a.ending
                        and b.date>='01/01/2008'
                        order by a.permno ;
                        """, date_cols=['start', 'ending', 'date'])
sp500.head(10)
# Out:
#    permno      start     ending       date       ret        vol    prc spread  \
# 0   10078 1992-08-20 2010-01-28 2008-01-31 -0.034749  3048974.0  17.50   None
# 1   10078 1992-08-20 2010-01-28 2008-02-29 -0.062857  2265659.0  16.40   None
# 2   10078 1992-08-20 2010-01-28 2008-03-31 -0.053049  2367471.0  15.53   None
# 3   10078 1992-08-20 2010-01-28 2008-04-30  0.008371  2189775.0  15.66   None
# 4   10078 1992-08-20 2010-01-28 2008-05-30 -0.173052  5221244.0  12.95   None
# 5   10078 1992-08-20 2010-01-28 2008-06-30 -0.159846  3411786.0  10.88   None
# 6   10078 1992-08-20 2010-01-28 2008-07-31 -0.022978  4448763.0  10.63   None
# 7   10078 1992-08-20 2010-01-28 2008-08-29 -0.153340  3756307.0   9.00   None
# 8   10078 1992-08-20 2010-01-28 2008-09-30 -0.155556  3470283.0   7.60   None
# 9   10078 1992-08-20 2010-01-28 2008-10-31 -0.394737  3887882.0   4.60   None
#
#      shrout      retx   bidlo  askhi
# 0  792771.0 -0.034749  14.820  17.55
# 1  792771.0 -0.062857  16.330  17.70
# 2  782000.0 -0.053049  15.530  16.96
# 3  781784.0  0.008371  14.880  16.00
# 4  781784.0 -0.173052  12.638  16.33
# 5  752000.0 -0.159846  10.880  12.94
# 6  752000.0 -0.022978   8.780  10.79
# 7  752953.0 -0.153340   8.860  10.86
# 8  739000.0 -0.155556   6.750   9.39
# 9  738585.0 -0.394737   4.440   7.49

# %% [markdown]
# ### Step 3: Add Other Company Identifiers from CRSP.MSENAMES
# - This step aims to add TICKER, SHRCD, EXCHCD and etc.

# %%
# Add Other Descriptive Variables

mse = conn.raw_sql("""
                        select comnam, ncusip, namedt, nameendt,naics, 
                        permno, shrcd, exchcd, hsiccd, ticker
                        from crsp.msenames as a
                        """, date_cols=['namedt', 'nameendt'])

# if nameendt is missing then set to today date
# only keep the most recent company name 
mse['nameendt']=mse['nameendt'].fillna(pd.to_datetime('today'))
mse.head()
# Out:
#                       comnam    ncusip     namedt   nameendt naics  permno  \
# 0  OPTIMUM MANUFACTURING INC  68391610 1986-01-07 1986-12-03  None   10000
# 1  OPTIMUM MANUFACTURING INC  68391610 1986-12-04 1987-03-09  None   10000
# 2  OPTIMUM MANUFACTURING INC  68391610 1987-03-10 1987-06-11  None   10000
# 3         GREAT FALLS GAS CO  39040610 1986-01-09 1993-11-21  None   10001
# 4            ENERGY WEST INC  29274A10 1993-11-22 2004-06-09  None   10001
#
#    shrcd  exchcd  hsiccd ticker
# 0     10       3    3990  OMFGA
# 1     10       3    3990  OMFGA
# 2     10       3    3990  OMFGA
# 3     11       3    4925   GFGC
# 4     11       3    4925   EWST

# %%
# Merge with SP500 data
sp500_full = pd.merge(sp500, mse, how = 'left', on = 'permno')

# Impose the date range restrictions, to ensure the name is valid during on a specific date
sp500_full = sp500_full.loc[(sp500_full.date>=sp500_full.namedt) \
                            & (sp500_full.date<=sp500_full.nameendt)]
sp500_full.head(10)
# Out:
#     permno      start     ending       date       ret        vol    prc  \
# 4    10078 1992-08-20 2010-01-28 2008-01-31 -0.034749  3048974.0  17.50
# 9    10078 1992-08-20 2010-01-28 2008-02-29 -0.062857  2265659.0  16.40
# 14   10078 1992-08-20 2010-01-28 2008-03-31 -0.053049  2367471.0  15.53
# 19   10078 1992-08-20 2010-01-28 2008-04-30  0.008371  2189775.0  15.66
# 24   10078 1992-08-20 2010-01-28 2008-05-30 -0.173052  5221244.0  12.95
# 29   10078 1992-08-20 2010-01-28 2008-06-30 -0.159846  3411786.0  10.88
# 34   10078 1992-08-20 2010-01-28 2008-07-31 -0.022978  4448763.0  10.63
# 39   10078 1992-08-20 2010-01-28 2008-08-29 -0.153340  3756307.0   9.00
# 44   10078 1992-08-20 2010-01-28 2008-09-30 -0.155556  3470283.0   7.60
# 49   10078 1992-08-20 2010-01-28 2008-10-31 -0.394737  3887882.0   4.60
#
#    spread    shrout      retx   bidlo  askhi                comnam    ncusip  \
# 4    None  792771.0 -0.034749  14.820  17.55  SUN MICROSYSTEMS INC  86681020
# 9    None  792771.0 -0.062857  16.330  17.70  SUN MICROSYSTEMS INC  86681020
# 14   None  782000.0 -0.053049  15.530  16.96  SUN MICROSYSTEMS INC  86681020
# 19   None  781784.0  0.008371  14.880  16.00  SUN MICROSYSTEMS INC  86681020
# 24   None  781784.0 -0.173052  12.638  16.33  SUN MICROSYSTEMS INC  86681020
# 29   None  752000.0 -0.159846  10.880  12.94  SUN MICROSYSTEMS INC  86681020
# 34   None  752000.0 -0.022978   8.780  10.79  SUN MICROSYSTEMS INC  86681020
# 39   None  752953.0 -0.153340   8.860  10.86  SUN MICROSYSTEMS INC  86681020
# 44   None  739000.0 -0.155556   6.750   9.39  SUN MICROSYSTEMS INC  86681020
# 49   None  738585.0 -0.394737   4.440   7.49  SUN MICROSYSTEMS INC  86681020
#
#        namedt   nameendt   naics  shrcd  exchcd  hsiccd ticker
# 4  2007-12-11 2010-01-26  334111     11       3    3571   JAVA
# 9  2007-12-11 2010-01-26  334111     11       3    3571   JAVA
# 14 2007-12-11 2010-01-26  334111     11       3    3571   JAVA
# 19 2007-12-11 2010-01-26  334111     11       3    3571   JAVA
# 24 2007-12-11 2010-01-26  334111     11       3    3571   JAVA
# 29 2007-12-11 2010-01-26  334111     11       3    3571   JAVA
# 34 2007-12-11 2010-01-26  334111     11       3    3571   JAVA
# 39 2007-12-11 2010-01-26  334111     11       3    3571   JAVA
# 44 2007-12-11 2010-01-26  334111     11       3    3571   JAVA
# 49 2007-12-11 2010-01-26  334111     11       3    3571   JAVA

# %% [markdown]
# ### Step 4: Add Compustat Identifiers
# - Link with Compustat's GVKEY and IID if need to work with fundamental data
# - Linkage is done through crsp.ccmxpf_linktable

# %%
# Linking with Compustat through CCM

ccm=conn.raw_sql("""
                  select gvkey, liid as iid, lpermno as permno, linktype, linkprim, 
                  linkdt, linkenddt
                  from crsp.ccmxpf_linktable
                  where substr(linktype,1,1)='L'
                  and (linkprim ='C' or linkprim='P')
                  """, date_cols=['linkdt', 'linkenddt'])

# if linkenddt is missing then set to today date
ccm['linkenddt']=ccm['linkenddt'].fillna(pd.to_datetime('today'))

# %%
ccm.sample(10)
# Out:
#         gvkey iid   permno linktype linkprim     linkdt  \
# 14878  017076  01  10297.0       LC        P 1986-05-27
# 32159  127378  01  87489.0       LC        P 1999-12-10
# 14442  016481  01  75777.0       LC        C 1989-06-13
# 20760  029455  01  80081.0       LU        P 1993-12-21
# 15827  019529  01  14425.0       LC        P 2014-01-15
# 37714  247881  90  13926.0       LC        P 2013-05-02
# 27678  043545  01  24525.0       LS        P 2023-11-02
# 31540  119297  01  90046.0       LC        P 2004-02-17
# 10805  011665  01  93252.0       LU        C 1985-04-30
# 16433  021158  01  76116.0       LC        C 1990-03-27
#
#                        linkenddt
# 14878 2017-01-31 00:00:00.000000
# 32159 2004-07-30 00:00:00.000000
# 14442 1993-04-07 00:00:00.000000
# 20760 2018-04-30 00:00:00.000000
# 15827 2018-10-31 00:00:00.000000
# 37714 2021-05-28 00:00:00.000000
# 27678 2024-11-16 10:21:17.065575
# 31540 2008-07-03 00:00:00.000000
# 10805 1993-01-19 00:00:00.000000
# 16433 1999-01-29 00:00:00.000000

# %%
# Merge the CCM data with S&P500 data
# First just link by matching PERMNO
sp500ccm = pd.merge(sp500_full, ccm, how='left', on=['permno'])

# Then set link date bounds
sp500ccm = sp500ccm.loc[(sp500ccm['date']>=sp500ccm['linkdt'])\
                        &(sp500ccm['date']<=sp500ccm['linkenddt'])]
sp500ccm.head(10)
#sp500ccm.sample(5)
# Out:
#    permno      start     ending       date       ret        vol    prc spread  \
# 0   10078 1992-08-20 2010-01-28 2008-01-31 -0.034749  3048974.0  17.50   None
# 1   10078 1992-08-20 2010-01-28 2008-02-29 -0.062857  2265659.0  16.40   None
# 2   10078 1992-08-20 2010-01-28 2008-03-31 -0.053049  2367471.0  15.53   None
# 3   10078 1992-08-20 2010-01-28 2008-04-30  0.008371  2189775.0  15.66   None
# 4   10078 1992-08-20 2010-01-28 2008-05-30 -0.173052  5221244.0  12.95   None
# 5   10078 1992-08-20 2010-01-28 2008-06-30 -0.159846  3411786.0  10.88   None
# 6   10078 1992-08-20 2010-01-28 2008-07-31 -0.022978  4448763.0  10.63   None
# 7   10078 1992-08-20 2010-01-28 2008-08-29 -0.153340  3756307.0   9.00   None
# 8   10078 1992-08-20 2010-01-28 2008-09-30 -0.155556  3470283.0   7.60   None
# 9   10078 1992-08-20 2010-01-28 2008-10-31 -0.394737  3887882.0   4.60   None
#
#      shrout      retx   bidlo  askhi                comnam    ncusip  \
# 0  792771.0 -0.034749  14.820  17.55  SUN MICROSYSTEMS INC  86681020
# 1  792771.0 -0.062857  16.330  17.70  SUN MICROSYSTEMS INC  86681020
# 2  782000.0 -0.053049  15.530  16.96  SUN MICROSYSTEMS INC  86681020
# 3  781784.0  0.008371  14.880  16.00  SUN MICROSYSTEMS INC  86681020
# 4  781784.0 -0.173052  12.638  16.33  SUN MICROSYSTEMS INC  86681020
# 5  752000.0 -0.159846  10.880  12.94  SUN MICROSYSTEMS INC  86681020
# 6  752000.0 -0.022978   8.780  10.79  SUN MICROSYSTEMS INC  86681020
# 7  752953.0 -0.153340   8.860  10.86  SUN MICROSYSTEMS INC  86681020
# 8  739000.0 -0.155556   6.750   9.39  SUN MICROSYSTEMS INC  86681020
# 9  738585.0 -0.394737   4.440   7.49  SUN MICROSYSTEMS INC  86681020
#
#       namedt   nameendt   naics  shrcd  exchcd  hsiccd ticker   gvkey iid  \
# 0 2007-12-11 2010-01-26  334111     11       3    3571   JAVA  012136  01
# 1 2007-12-11 2010-01-26  334111     11       3    3571   JAVA  012136  01
# 2 2007-12-11 2010-01-26  334111     11       3    3571   JAVA  012136  01
# 3 2007-12-11 2010-01-26  334111     11       3    3571   JAVA  012136  01
# 4 2007-12-11 2010-01-26  334111     11       3    3571   JAVA  012136  01
# 5 2007-12-11 2010-01-26  334111     11       3    3571   JAVA  012136  01
# 6 2007-12-11 2010-01-26  334111     11       3    3571   JAVA  012136  01
# 7 2007-12-11 2010-01-26  334111     11       3    3571   JAVA  012136  01
# 8 2007-12-11 2010-01-26  334111     11       3    3571   JAVA  012136  01
# 9 2007-12-11 2010-01-26  334111     11       3    3571   JAVA  012136  01
#
#   linktype linkprim     linkdt  linkenddt
# 0       LC        P 1986-03-04 2010-01-29
# 1       LC        P 1986-03-04 2010-01-29
# 2       LC        P 1986-03-04 2010-01-29
# 3       LC        P 1986-03-04 2010-01-29
# 4       LC        P 1986-03-04 2010-01-29
# 5       LC        P 1986-03-04 2010-01-29
# 6       LC        P 1986-03-04 2010-01-29
# 7       LC        P 1986-03-04 2010-01-29
# 8       LC        P 1986-03-04 2010-01-29
# 9       LC        P 1986-03-04 2010-01-29

# %%
# Rearrange columns for final output

sp500ccm = sp500ccm.drop(columns=['namedt', 'nameendt', \
                                  'linktype', 'linkprim', 'linkdt', 'linkenddt'])
sp500ccm = sp500ccm[['date', 'permno', 'comnam', 'ncusip', 'shrcd', 'exchcd', 'naics','hsiccd', 'ticker', \
                     'gvkey', 'iid', 'start', 'ending', 'ret','vol', 'prc', 'spread', 'shrout',	'retx',	'bidlo', 'askhi']]
sp500ccm.head(10)
# Out:
#         date  permno                comnam    ncusip  shrcd  exchcd   naics  \
# 0 2008-01-31   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 1 2008-02-29   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 2 2008-03-31   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 3 2008-04-30   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 4 2008-05-30   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 5 2008-06-30   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 6 2008-07-31   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 7 2008-08-29   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 8 2008-09-30   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 9 2008-10-31   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
#
#    hsiccd ticker   gvkey iid      start     ending       ret        vol  \
# 0    3571   JAVA  012136  01 1992-08-20 2010-01-28 -0.034749  3048974.0
# 1    3571   JAVA  012136  01 1992-08-20 2010-01-28 -0.062857  2265659.0
# 2    3571   JAVA  012136  01 1992-08-20 2010-01-28 -0.053049  2367471.0
# 3    3571   JAVA  012136  01 1992-08-20 2010-01-28  0.008371  2189775.0
# 4    3571   JAVA  012136  01 1992-08-20 2010-01-28 -0.173052  5221244.0
# 5    3571   JAVA  012136  01 1992-08-20 2010-01-28 -0.159846  3411786.0
# 6    3571   JAVA  012136  01 1992-08-20 2010-01-28 -0.022978  4448763.0
# 7    3571   JAVA  012136  01 1992-08-20 2010-01-28 -0.153340  3756307.0
# 8    3571   JAVA  012136  01 1992-08-20 2010-01-28 -0.155556  3470283.0
# 9    3571   JAVA  012136  01 1992-08-20 2010-01-28 -0.394737  3887882.0
#
#      prc spread    shrout      retx   bidlo  askhi
# 0  17.50   None  792771.0 -0.034749  14.820  17.55
# 1  16.40   None  792771.0 -0.062857  16.330  17.70
# 2  15.53   None  782000.0 -0.053049  15.530  16.96
# 3  15.66   None  781784.0  0.008371  14.880  16.00
# 4  12.95   None  781784.0 -0.173052  12.638  16.33
# 5  10.88   None  752000.0 -0.159846  10.880  12.94
# 6  10.63   None  752000.0 -0.022978   8.780  10.79
# 7   9.00   None  752953.0 -0.153340   8.860  10.86
# 8   7.60   None  739000.0 -0.155556   6.750   9.39
# 9   4.60   None  738585.0 -0.394737   4.440   7.49

# %%
#count the list of s&p every date
cnt = sp500ccm.groupby(['date'])['permno'].count().reset_index().rename(columns={'permno':'npermno'})
cnt.sample(10)
# Out:
#           date  npermno
# 129 2018-10-31      501
# 92  2015-09-30      501
# 16  2009-05-29      501
# 81  2014-10-31      501
# 156 2021-01-29      500
# 147 2020-04-30      501
# 161 2021-06-30      500
# 89  2015-06-30      500
# 137 2019-06-28      501
# 11  2008-12-31      501

# %%
sp500ccm.sample(10)
# Out:
#              date  permno                       comnam    ncusip  shrcd  \
# 54773  2011-12-30   45241              FOREST LABS INC  34583810     11
# 103532 2016-11-30   87184                  RED HAT INC  75657710     11
# 114927 2015-11-30   91233               MASTERCARD INC  57636Q10     11
# 739    2010-09-30   10145  HONEYWELL INTERNATIONAL INC  43851610     11
# 48762  2011-03-31   35051                    PALL CORP  69642930     11
# 25690  2008-03-31   20415       LEUCADIA NATIONAL CORP  52728810     11
# 2274   2011-12-30   11081                     DELL INC  24702R10     11
# 43699  2011-03-31   26403               DISNEY WALT CO  25468710     11
# 3262   2016-06-30   11552                 CELGENE CORP  15102010     11
# 6942   2011-06-30   12140                GOODRICH CORP  38238810     11
#
#         exchcd   naics  hsiccd ticker   gvkey iid      start     ending  \
# 54773        1  325412    2834    FRX  004843  01 2000-11-22 2014-06-30
# 103532       1  518210    7372    RHT  122841  01 2009-07-27 2019-07-12
# 114927       1  541199    7389     MA  160225  01 2008-07-18 2023-12-29
# 739          1  336412    3724    HON  001300  01 1925-12-31 2023-12-29
# 48762        1  333999    3569    PLL  008304  01 1987-12-31 2015-08-28
# 25690        1  321912    6211    LUK  006682  01 2007-08-27 2019-09-25
# 2274         3  334113    3570   DELL  014489  01 1996-09-06 2013-10-28
# 43699        1  713110    4833    DIS  003980  01 1976-07-01 2023-12-29
# 3262         3  325412    2890   CELG  013599  01 2006-11-06 2019-11-20
# 6942         1  336414    3761     GR  005229  01 1957-03-01 2012-07-30
#
#              ret        vol    prc spread     shrout      retx  bidlo   askhi
# 54773   0.010013   387512.0  30.26   None   267153.0  0.010013  28.55   30.45
# 103532  0.021433   234726.0  79.11   None   179596.0  0.021433  74.45   80.00
# 114927 -0.010809   730981.0  97.92   None  1100234.0 -0.010809  96.86  101.50
# 739     0.124936  1016920.0  43.94   None   772210.0  0.124936  40.88   44.46
# 48762   0.059787   229246.0  57.61   None   116120.0  0.059787  53.44   57.61
# 25690  -0.000884   227141.0  45.22   None   222576.0 -0.000884  43.30   46.89
# 2274   -0.071701  3257409.0  14.63   None  1796509.0 -0.071701  14.63   15.93
# 43699  -0.014861  2132182.0  43.09   None  1899069.0 -0.014861  40.60   44.07
# 3262   -0.065296  1051120.0  98.63   None   775000.0 -0.065296  94.85  108.24
# 6942    0.094054   294107.0  95.50   None   124871.0  0.094054  84.60   95.50

# %%
### Add CIKs and Link with SEC Index Files using CIK

names = conn.raw_sql(""" select gvkey, cik, sic, gind, gsubind from comp.names """)
# Merge sp500 constituents table with names table
sp500cik = pd.merge(sp500ccm, names, on='gvkey',  how='left')
sp500cik['gvkey'] = pd.to_numeric(sp500cik['gvkey'], errors='coerce').fillna(0).astype(int)
sp500cik.head()
# Out:
#         date  permno                comnam    ncusip  shrcd  exchcd   naics  \
# 0 2008-01-31   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 1 2008-02-29   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 2 2008-03-31   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 3 2008-04-30   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 4 2008-05-30   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
#
#    hsiccd ticker  gvkey iid      start     ending       ret        vol    prc  \
# 0    3571   JAVA  12136  01 1992-08-20 2010-01-28 -0.034749  3048974.0  17.50
# 1    3571   JAVA  12136  01 1992-08-20 2010-01-28 -0.062857  2265659.0  16.40
# 2    3571   JAVA  12136  01 1992-08-20 2010-01-28 -0.053049  2367471.0  15.53
# 3    3571   JAVA  12136  01 1992-08-20 2010-01-28  0.008371  2189775.0  15.66
# 4    3571   JAVA  12136  01 1992-08-20 2010-01-28 -0.173052  5221244.0  12.95
#
#   spread    shrout      retx   bidlo  askhi         cik   sic    gind  \
# 0   None  792771.0 -0.034749  14.820  17.55  0000709519  3571  452020
# 1   None  792771.0 -0.062857  16.330  17.70  0000709519  3571  452020
# 2   None  782000.0 -0.053049  15.530  16.96  0000709519  3571  452020
# 3   None  781784.0  0.008371  14.880  16.00  0000709519  3571  452020
# 4   None  781784.0 -0.173052  12.638  16.33  0000709519  3571  452020
#
#     gsubind
# 0  45202010
# 1  45202010
# 2  45202010
# 3  45202010
# 4  45202010

# %%
# enerate year-month
#sp500cik = sp500cik.copy()
sp500cik['ym'] = sp500cik['date'].dt.strftime('%Y-%m')

sp500cik.head()
# Out:
#         date  permno                comnam    ncusip  shrcd  exchcd   naics  \
# 0 2008-01-31   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 1 2008-02-29   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 2 2008-03-31   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 3 2008-04-30   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
# 4 2008-05-30   10078  SUN MICROSYSTEMS INC  86681020     11       3  334111
#
#    hsiccd ticker  gvkey iid      start     ending       ret        vol    prc  \
# 0    3571   JAVA  12136  01 1992-08-20 2010-01-28 -0.034749  3048974.0  17.50
# 1    3571   JAVA  12136  01 1992-08-20 2010-01-28 -0.062857  2265659.0  16.40
# 2    3571   JAVA  12136  01 1992-08-20 2010-01-28 -0.053049  2367471.0  15.53
# 3    3571   JAVA  12136  01 1992-08-20 2010-01-28  0.008371  2189775.0  15.66
# 4    3571   JAVA  12136  01 1992-08-20 2010-01-28 -0.173052  5221244.0  12.95
#
#   spread    shrout      retx   bidlo  askhi         cik   sic    gind  \
# 0   None  792771.0 -0.034749  14.820  17.55  0000709519  3571  452020
# 1   None  792771.0 -0.062857  16.330  17.70  0000709519  3571  452020
# 2   None  782000.0 -0.053049  15.530  16.96  0000709519  3571  452020
# 3   None  781784.0  0.008371  14.880  16.00  0000709519  3571  452020
# 4   None  781784.0 -0.173052  12.638  16.33  0000709519  3571  452020
#
#     gsubind       ym
# 0  45202010  2008-01
# 1  45202010  2008-02
# 2  45202010  2008-03
# 3  45202010  2008-04
# 4  45202010  2008-05

# %%
#count the list of s&p every date
cnt = sp500cik.groupby(['date'])['permno'].count().reset_index().rename(columns={'permno':'npermno'})
cnt.sample(10)
# Out:
#           date  npermno
# 101 2016-06-30      501
# 24  2010-01-29      501
# 111 2017-04-28      501
# 44  2011-09-30      501
# 132 2019-01-31      501
# 129 2018-10-31      501
# 164 2021-09-30      500
# 65  2013-06-28      501
# 167 2021-12-31      500
# 147 2020-04-30      501

# %% [markdown]
# ### Step 5: Read Transcriprts
# - Link with Compustat's GVKEY with Company Id
# - Merge with transcript table

# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
Ear_call = pd.read_csv('Transcript-WRDS/Ear_calls2019.csv')

# Display the first few rows of the DataFrame
Ear_call.head()
# Out:
#    companyid     keydevid  transcriptid  \
# 0   340577.0  597169932.0     1632539.0
# 1   340577.0  597169932.0     1632539.0
# 2   340577.0  597169932.0     1632539.0
# 3   340577.0  597169932.0     1632539.0
# 4   340577.0  597169932.0     1632539.0
#
#                                             headline mostimportantdateutc  \
# 0  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
# 1  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
# 2  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
# 3  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
# 4  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
#
#   keydeveventtypename                      companyname  audiolengthsec  \
# 0      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
# 1      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
# 2      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
# 3      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
# 4      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
#
#    isdelayed_flag  transcriptid.1  transcriptcomponentid  componentorder  \
# 0               0       1632539.0             64297491.0               0
# 1               0       1632539.0             64297492.0               1
# 2               0       1632539.0             64297493.0               2
# 3               0       1632539.0             64297494.0               3
# 4               0       1632539.0             64297495.0               4
#
#    transcriptcomponenttypeid    transcriptcomponenttypename  \
# 0                          1  Presentation Operator Message
# 1                          2               Presenter Speech
# 2                          2               Presenter Speech
# 3                          2               Presenter Speech
# 4                          2               Presenter Speech
#
#    transcriptpersonid transcriptpersonname speakertypename  word_count  \
# 0                 1.0             Operator        Operator        47.0
# 1             57497.0           Gary Maier      Executives       232.0
# 2            112511.0         Selwyn Joffe      Executives       773.0
# 3            112510.0            David Lee      Executives      1601.0
# 4            112511.0         Selwyn Joffe      Executives       280.0
#
#                                        componenttext
# 0  Good day, ladies and gentlemen, and welcome to...
# 1  Thank you. Thank you, all, for joining us for ...
# 2  All right. Thank you so much, Gary. I apprecia...
# 3  Thank you, Selwyn. To begin, I encourage every...
# 4  Thanks, David. We're excited by expanding low-...

# %%
type = Ear_call['speakertypename'].unique()
print(type)
# Out:
# ['Operator' 'Executives' 'Analysts' 'Shareholders' 'Attendees']

# %%
Ear_call['mostimportantdateutc'] = pd.to_datetime( Ear_call['mostimportantdateutc'])
Ear_call['ym'] =  Ear_call['mostimportantdateutc'].dt.strftime('%Y-%m')
#Ear_call.drop(columns=['B'], inplace=True)
Ear_call.head(2)
# Out:
#    companyid     keydevid  transcriptid  \
# 0   340577.0  597169932.0     1632539.0
# 1   340577.0  597169932.0     1632539.0
#
#                                             headline mostimportantdateutc  \
# 0  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
# 1  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
#
#   keydeveventtypename                      companyname  audiolengthsec  \
# 0      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
# 1      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
#
#    isdelayed_flag  transcriptid.1  transcriptcomponentid  componentorder  \
# 0               0       1632539.0             64297491.0               0
# 1               0       1632539.0             64297492.0               1
#
#    transcriptcomponenttypeid    transcriptcomponenttypename  \
# 0                          1  Presentation Operator Message
# 1                          2               Presenter Speech
#
#    transcriptpersonid transcriptpersonname speakertypename  word_count  \
# 0                 1.0             Operator        Operator        47.0
# 1             57497.0           Gary Maier      Executives       232.0
#
#                                        componenttext       ym
# 0  Good day, ladies and gentlemen, and welcome to...  2019-01
# 1  Thank you. Thank you, all, for joining us for ...  2019-01

# %%
gvkey = pd.read_csv('Transcript-WRDS/gvkey.csv')

# Replace NaN values in 'startdate' with an extremely small date
gvkey['startdate'] = gvkey['startdate'].fillna(pd.to_datetime('1677-09-22'))
gvkey.head()
# Out:
#    companyid   gvkey            startdate                     enddate  \
# 0    18507.0  235716  1677-09-22 00:00:00  2024-07-24 19:02:02.807778
# 1    18511.0  210835  1677-09-22 00:00:00  2024-07-24 19:02:02.807778
# 2    18527.0  210418  1677-09-22 00:00:00  2024-07-24 19:02:02.807778
# 3    18671.0   29751  1677-09-22 00:00:00  2024-07-24 19:02:02.807778
# 4    18711.0   28349  1677-09-22 00:00:00  2024-07-24 19:02:02.807778
#
#                 companyname
# 0             2M Invest A/S
# 1              3i Group plc
# 2                   ABB Ltd
# 3     Albemarle Corporation
# 4  The Allstate Corporation

# %%
# add date restrictions 
Ear_call = pd.merge(Ear_call, gvkey, on=['companyid'], how='left')
Ear_call.head()
# Out:
#    companyid     keydevid  transcriptid  \
# 0   340577.0  597169932.0     1632539.0
# 1   340577.0  597169932.0     1632539.0
# 2   340577.0  597169932.0     1632539.0
# 3   340577.0  597169932.0     1632539.0
# 4   340577.0  597169932.0     1632539.0
#
#                                             headline mostimportantdateutc  \
# 0  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
# 1  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
# 2  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
# 3  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
# 4  Motorcar Parts of America, Inc., Q2 2019 Earni...           2019-01-08
#
#   keydeveventtypename                    companyname_x  audiolengthsec  \
# 0      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
# 1      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
# 2      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
# 3      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
# 4      Earnings Calls  Motorcar Parts of America, Inc.          3973.0
#
#    isdelayed_flag  transcriptid.1  transcriptcomponentid  componentorder  \
# 0               0       1632539.0             64297491.0               0
# 1               0       1632539.0             64297492.0               1
# 2               0       1632539.0             64297493.0               2
# 3               0       1632539.0             64297494.0               3
# 4               0       1632539.0             64297495.0               4
#
#    transcriptcomponenttypeid    transcriptcomponenttypename  \
# 0                          1  Presentation Operator Message
# 1                          2               Presenter Speech
# 2                          2               Presenter Speech
# 3                          2               Presenter Speech
# 4                          2               Presenter Speech
#
#    transcriptpersonid transcriptpersonname speakertypename  word_count  \
# 0                 1.0             Operator        Operator        47.0
# 1             57497.0           Gary Maier      Executives       232.0
# 2            112511.0         Selwyn Joffe      Executives       773.0
# 3            112510.0            David Lee      Executives      1601.0
# 4            112511.0         Selwyn Joffe      Executives       280.0
#
#                                        componenttext       ym    gvkey  \
# 0  Good day, ladies and gentlemen, and welcome to...  2019-01  29930.0
# 1  Thank you. Thank you, all, for joining us for ...  2019-01  29930.0
# 2  All right. Thank you so much, Gary. I apprecia...  2019-01  29930.0
# 3  Thank you, Selwyn. To begin, I encourage every...  2019-01  29930.0
# 4  Thanks, David. We're excited by expanding low-...  2019-01  29930.0
#
#              startdate                     enddate  \
# 0  1677-09-22 00:00:00  2024-07-24 19:02:02.807778
# 1  1677-09-22 00:00:00  2024-07-24 19:02:02.807778
# 2  1677-09-22 00:00:00  2024-07-24 19:02:02.807778
# 3  1677-09-22 00:00:00  2024-07-24 19:02:02.807778
# 4  1677-09-22 00:00:00  2024-07-24 19:02:02.807778
#
#                      companyname_y
# 0  Motorcar Parts of America, Inc.
# 1  Motorcar Parts of America, Inc.
# 2  Motorcar Parts of America, Inc.
# 3  Motorcar Parts of America, Inc.
# 4  Motorcar Parts of America, Inc.

# %%
# Ensure that all date columns are in datetime format
Ear_call['startdate'] = pd.to_datetime(Ear_call['startdate'])


# Then set link date bounds
Ear_call = Ear_call.loc[(Ear_call['mostimportantdateutc']>=Ear_call['startdate'])\
                        &(Ear_call['mostimportantdateutc']<=Ear_call['enddate'])]

# %%
Ear_call.sample()
# Out:
#        companyid     keydevid  transcriptid  \
# 61154    29002.0  597010620.0     1647662.0
#
#                                                 headline mostimportantdateutc  \
# 61154  Gilead Sciences, Inc., Q4 2018 Earnings Call, ...           2019-02-04
#
#       keydeveventtypename          companyname_x  audiolengthsec  \
# 61154      Earnings Calls  Gilead Sciences, Inc.          3976.0
#
#        isdelayed_flag  transcriptid.1  transcriptcomponentid  componentorder  \
# 61154               0       1647662.0             64949997.0              11
#
#        transcriptcomponenttypeid transcriptcomponenttypename  \
# 61154                          4                      Answer
#
#        transcriptpersonid transcriptpersonname speakertypename  word_count  \
# 61154            289293.0          Gregg Alton      Executives       117.0
#
#                                            componenttext       ym    gvkey  \
# 61154  Sure. This is Gregg Alton. I'll take this ques...  2019-02  24856.0
#
#        startdate                     enddate          companyname_y
# 61154 1677-09-22  2024-07-24 19:02:02.807778  Gilead Sciences, Inc.

# %%
# merge sp500cik with transcript
# Merge DataFrames on 'id' and 'date'
#SP_500 = pd.merge(sp500cik,Ear2023, left_on=['gvkey','ym'], right_on=['gvkey_x','ym'],how='inner')
SP_500 = pd.merge(sp500cik, Ear_call, on=['gvkey','ym'],how='inner')

SP_500.head()
# Out:
#         date  permno       comnam    ncusip  shrcd  exchcd   naics  hsiccd  \
# 0 2019-03-29   10104  ORACLE CORP  68389X10     11       1  511210    7379
# 1 2019-03-29   10104  ORACLE CORP  68389X10     11       1  511210    7379
# 2 2019-03-29   10104  ORACLE CORP  68389X10     11       1  511210    7379
# 3 2019-03-29   10104  ORACLE CORP  68389X10     11       1  511210    7379
# 4 2019-03-29   10104  ORACLE CORP  68389X10     11       1  511210    7379
#
#   ticker  gvkey iid      start     ending       ret        vol    prc spread  \
# 0   ORCL  12142  01 1989-08-03 2023-12-29  0.030309  3706972.0  53.71   None
# 1   ORCL  12142  01 1989-08-03 2023-12-29  0.030309  3706972.0  53.71   None
# 2   ORCL  12142  01 1989-08-03 2023-12-29  0.030309  3706972.0  53.71   None
# 3   ORCL  12142  01 1989-08-03 2023-12-29  0.030309  3706972.0  53.71   None
# 4   ORCL  12142  01 1989-08-03 2023-12-29  0.030309  3706972.0  53.71   None
#
#       shrout      retx  bidlo  askhi         cik   sic    gind   gsubind  \
# 0  3417654.0  0.030309  52.04  54.04  0001341439  7372  451030  45103020
# 1  3417654.0  0.030309  52.04  54.04  0001341439  7372  451030  45103020
# 2  3417654.0  0.030309  52.04  54.04  0001341439  7372  451030  45103020
# 3  3417654.0  0.030309  52.04  54.04  0001341439  7372  451030  45103020
# 4  3417654.0  0.030309  52.04  54.04  0001341439  7372  451030  45103020
#
#         ym  companyid     keydevid  transcriptid  \
# 0  2019-03    22247.0  605489888.0     1690659.0
# 1  2019-03    22247.0  605489888.0     1690659.0
# 2  2019-03    22247.0  605489888.0     1690659.0
# 3  2019-03    22247.0  605489888.0     1690659.0
# 4  2019-03    22247.0  605489888.0     1690659.0
#
#                                             headline mostimportantdateutc  \
# 0  Oracle Corporation, Q3 2019 Earnings Call, Mar...           2019-03-14
# 1  Oracle Corporation, Q3 2019 Earnings Call, Mar...           2019-03-14
# 2  Oracle Corporation, Q3 2019 Earnings Call, Mar...           2019-03-14
# 3  Oracle Corporation, Q3 2019 Earnings Call, Mar...           2019-03-14
# 4  Oracle Corporation, Q3 2019 Earnings Call, Mar...           2019-03-14
#
#   keydeveventtypename       companyname_x  audiolengthsec  isdelayed_flag  \
# 0      Earnings Calls  Oracle Corporation          2705.0               0
# 1      Earnings Calls  Oracle Corporation          2705.0               0
# 2      Earnings Calls  Oracle Corporation          2705.0               0
# 3      Earnings Calls  Oracle Corporation          2705.0               0
# 4      Earnings Calls  Oracle Corporation          2705.0               0
#
#    transcriptid.1  transcriptcomponentid  componentorder  \
# 0       1690659.0             66523222.0               0
# 1       1690659.0             66523223.0               1
# 2       1690659.0             66523224.0               2
# 3       1690659.0             66523225.0               3
# 4       1690659.0             66523226.0               4
#
#    transcriptcomponenttypeid    transcriptcomponenttypename  \
# 0                          1  Presentation Operator Message
# 1                          2               Presenter Speech
# 2                          2               Presenter Speech
# 3                          2               Presenter Speech
# 4                          2               Presenter Speech
#
#    transcriptpersonid transcriptpersonname speakertypename  word_count  \
# 0                 1.0             Operator        Operator        24.0
# 1            342663.0             Ken Bond      Executives       237.0
# 2            115766.0           Safra Catz      Executives       771.0
# 3            160882.0            Mark Hurd      Executives      1014.0
# 4            115765.0     Lawrence Ellison      Executives       311.0
#
#                                        componenttext  startdate  \
# 0  Welcome to Oracle's Third Quarter 2019 Earning... 1677-09-22
# 1  Thank you, operator. Good afternoon, everyone,... 1677-09-22
# 2  Thanks, Ken. Good afternoon, everyone. I'll fi... 1677-09-22
# 3  Thanks, Safra. Thanks. Solid quarter for us, f... 1677-09-22
# 4  Thank you, Mark. Oracle's future rests on 2 st... 1677-09-22
#
#                       enddate       companyname_y
# 0  2024-07-24 19:02:02.807778  Oracle Corporation
# 1  2024-07-24 19:02:02.807778  Oracle Corporation
# 2  2024-07-24 19:02:02.807778  Oracle Corporation
# 3  2024-07-24 19:02:02.807778  Oracle Corporation
# 4  2024-07-24 19:02:02.807778  Oracle Corporation

# %%
pd.set_option('display.max_rows', 100,'display.max_columns', 1000,"display.max_colwidth",100,'display.width',100)

SP_500.sample(10)
#datacsv.sample(10)

#sample.loc[sample.index[0:10], ['headline', 'mostimportantdateutc']]
# Out:
#              date  permno                           comnam    ncusip  shrcd  exchcd   naics  \
# 102305 2019-07-31   83111      ALEXION PHARMACEUTICALS INC  01535110     11       3  325412
# 121547 2019-12-31   89508                       CARMAX INC  14313010     11       1  441120
# 43252  2019-10-31   34032                       MASCO CORP  57459910     11       1  321918
# 47285  2019-08-30   39490                      APACHE CORP  03741110     11       1  211111
# 10469  2019-08-30   13142               CAPRI HOLDINGS LTD  G1890L10     12       1  315220
# 90009  2019-10-31   79057                        CHUBB LTD  H1467J10     12       1  524130
# 98238  2019-01-31   81540           AMERISOURCEBERGEN CORP  03073E10     11       1  424210
# 50299  2019-07-31   42877  HUNT J B TRANSPORT SERVICES INC  44565810     11       3  484121
# 115115 2019-07-31   87541           PACKAGING CORP AMERICA  69515610     11       1  322219
# 78221  2019-07-31   71175                       UNUM GROUP  91529Y10     11       1  524113
#
#         hsiccd ticker   gvkey iid      start     ending       ret        vol     prc spread  \
# 102305    2830   ALXN   62263  01 2012-05-25 2021-07-20 -0.135059   436569.0  113.29   None
# 121547    5521    KMX   64410  01 2010-06-28 2023-12-29 -0.098602   336180.0   87.67   None
# 43252     3432    MAS    7085  01 1981-06-18 2023-12-29  0.112884   633463.0   46.25   None
# 47285     1311    APA    1678  01 1997-07-28 2023-12-29 -0.116708  1264558.0   21.57   None
# 10469     6719   CPRI  198058  01 2013-11-13 2020-05-11 -0.258781   855219.0   26.38   None
# 90009     6331     CB   28034  01 2010-07-15 2023-12-29 -0.055872   399964.0  152.42   None
# 98238     5122    ABC   31673  01 2001-08-30 2023-12-29  0.120565   321494.0   83.37   None
# 50299     4213   JBHT    5783  01 2015-07-01 2023-12-29  0.119899   321784.0  102.37   None
# 115115    2631    PKG  128978  01 2017-07-26 2023-12-29  0.059274   305516.0  100.97   None
# 78221     6321    UNM   12726  01 1994-03-11 2021-09-17 -0.039195   429845.0   31.95   None
#
#           shrout      retx      bidlo   askhi         cik   sic    gind   gsubind       ym  \
# 102305  224227.0 -0.135059  112.36000  134.08  0000899866  2836  352010  35201010  2019-07
# 121547  163795.0 -0.098602   87.43000   99.05  0001170010  5500  255040  25504050  2019-12
# 43252   286073.0  0.109645   40.91000   46.25  0000062996  3430  201020  20102010  2019-10
# 47285   375959.0 -0.116708   19.93000   24.19  0001841666  1311  101020  10102020  2019-08
# 10469   151579.0 -0.258781   25.89000   33.97  0001530721  2300  252030  25203010  2019-08
# 90009   453202.0 -0.055872  148.24001  162.06  0000896159  6331  403010  40301040  2019-10
# 98238   211090.0  0.120565   73.37000   83.37  0001140859  5122  351020  35102010  2019-01
# 50299   106768.0  0.119899   87.63000  104.19  0000728535  4213  203040  20304030  2019-07
# 115115   94494.0  0.059274   97.12000  103.04  0000075677  2650  151030  15103020  2019-07
# 78221   208631.0 -0.047690   31.95000   34.60  0000005513  6321  403010  40301020  2019-07
#
#           companyid     keydevid  transcriptid  \
# 102305     347983.0  628779886.0     1779507.0
# 121547     356805.0  646836542.0     1887477.0
# 43252      181478.0  638167558.0     1849581.0
# 47285      169838.0  629966686.0     1796303.0
# 10469   143971118.0  630719436.0     1816972.0
# 90009      203028.0  596944293.0     1851250.0
# 98238       24809.0  597021097.0     1645738.0
# 50299      278576.0  626524826.0     1772580.0
# 115115      98885.0  625962876.0     1784560.0
# 78221      166762.0  626367326.0     1791054.0
#
#                                                                        headline  \
# 102305       Alexion Pharmaceuticals, Inc., Q2 2019 Earnings Call, Jul 24, 2019
# 121547                        CarMax, Inc., Q3 2020 Earnings Call, Dec 20, 2019
# 43252                    Masco Corporation, Q3 2019 Earnings Call, Oct 30, 2019
# 47285                   Apache Corporation, Q2 2019 Earnings Call, Aug 01, 2019
# 10469               Capri Holdings Limited, Q1 2020 Earnings Call, Aug 07, 2019
# 90009                        Chubb Limited, Q3 2019 Earnings Call, Oct 30, 2019
# 98238        AmerisourceBergen Corporation, Q1 2019 Earnings Call, Jan 31, 2019
# 50299   J.B. Hunt Transport Services, Inc., Q2 2019 Earnings Call, Jul 15, 2019
# 115115    Packaging Corporation of America, Q2 2019 Earnings Call, Jul 25, 2019
# 78221                           Unum Group, Q2 2019 Earnings Call, Jul 31, 2019
#
#        mostimportantdateutc keydeveventtypename                       companyname_x  \
# 102305           2019-07-24      Earnings Calls       Alexion Pharmaceuticals, Inc.
# 121547           2019-12-20      Earnings Calls                        CarMax, Inc.
# 43252            2019-10-30      Earnings Calls                   Masco Corporation
# 47285            2019-08-01      Earnings Calls                     APA Corporation
# 10469            2019-08-07      Earnings Calls              Capri Holdings Limited
# 90009            2019-10-30      Earnings Calls                       Chubb Limited
# 98238            2019-01-31      Earnings Calls                       Cencora, Inc.
# 50299            2019-07-15      Earnings Calls  J.B. Hunt Transport Services, Inc.
# 115115           2019-07-25      Earnings Calls    Packaging Corporation of America
# 78221            2019-07-31      Earnings Calls                          Unum Group
#
#         audiolengthsec  isdelayed_flag  transcriptid.1  transcriptcomponentid  componentorder  \
# 102305          3331.0               0       1779507.0             69663092.0               2
# 121547          2640.0               0       1887477.0             73910453.0              33
# 43252           3539.0               0       1849581.0             72350016.0              25
# 47285           3236.0               0       1796303.0             70344495.0              64
# 10469           3945.0               0       1816972.0             71118066.0               0
# 90009           3602.0               0       1851250.0             72429027.0              38
# 98238           3623.0               0       1645738.0             64859416.0              18
# 50299           3419.0               0       1772580.0             69402461.0              53
# 115115          2515.0               0       1784560.0             69885201.0               6
# 78221           3981.0               0       1791054.0             70147316.0              58
#
#         transcriptcomponenttypeid           transcriptcomponenttypename  transcriptpersonid  \
# 102305                          2                      Presenter Speech            331037.0
# 121547                          3                              Question            238660.0
# 43252                           3                              Question            363036.0
# 47285                           4                                Answer            304916.0
# 10469                           1         Presentation Operator Message                 1.0
# 90009                           4                                Answer             95732.0
# 98238                           7  Question and Answer Operator Message                 1.0
# 50299                           3                              Question            199342.0
# 115115                          7  Question and Answer Operator Message                 1.0
# 78221                           3                              Question            356732.0
#
#         transcriptpersonname speakertypename  word_count  \
# 102305        Ludwig Hantson      Executives       464.0
# 121547  Armintas Sinkevicius        Analysts        52.0
# 43252           Michael Dahl        Analysts        91.0
# 47285          Stephen Riney      Executives       131.0
# 10469               Operator        Operator        43.0
# 90009      Evan G. Greenberg      Executives        10.0
# 98238               Operator        Operator        12.0
# 50299           David Vernon        Analysts        14.0
# 115115              Operator        Operator        15.0
# 78221             John Nadel        Analysts       109.0
#
#                                                                                               componenttext  \
# 102305  Thank you, Susan, and good morning, everyone. We've made great progress so far this year further...
# 121547  7.5% same-store sales growth year-over-year, that's quite a strong number. How do we think about...
# 43252   That's helpful. A follow-up question, just shifting gears to paint and the environment there. Ob...
# 47285   Yes. We're probably not going to shed a whole of details on that. But basically, it's structure....
# 10469   Good day, and welcome to the Capri Holdings Limited First Quarter 2020 Earnings Conference Call....
# 90009                                                          Am I making sense? Am I being clear for you?
# 98238                                        Our next question is from the line of Lisa Gill with JPMorgan.
# 50299                       David Vernon of Bernstein. Dave, could you talk a little about how much OpEx...
# 115115    [Operator Instructions] Your first question is from the line of Brian Maguire with Goldman Sachs.
# 78221   Okay. I appreciate the commentary. And then if I could switch gears just to sort of long-term ca...
#
#         startdate                     enddate                       companyname_y
# 102305 1677-09-22  2024-07-24 19:02:02.807778       Alexion Pharmaceuticals, Inc.
# 121547 1677-09-22  2024-07-24 19:02:02.807778                        CarMax, Inc.
# 43252  1677-09-22  2024-07-24 19:02:02.807778                   Masco Corporation
# 47285  1677-09-22  2024-07-24 19:02:02.807778                     APA Corporation
# 10469  1677-09-22  2024-07-24 19:02:02.807778              Capri Holdings Limited
# 90009  1677-09-22  2024-07-24 19:02:02.807778                       Chubb Limited
# 98238  1677-09-22  2024-07-24 19:02:02.807778                       Cencora, Inc.
# 50299  1677-09-22  2024-07-24 19:02:02.807778  J.B. Hunt Transport Services, Inc.
# 115115 1677-09-22  2024-07-24 19:02:02.807778    Packaging Corporation of America
# 78221  1999-07-01  2024-07-24 19:02:02.807778                          Unum Group

# %%
# Convert date column to datetime if not already
SP_500['ym'] = pd.to_datetime(SP_500['ym'])

# Group by 'date' and calculate the number of unique 'id' values for each date
unique_comp = SP_500.groupby('ym')['gvkey'].nunique()

print(unique_comp)
# Out:
# ym
# 2019-01-01    197
# 2019-02-01    262
# 2019-03-01     34
# 2019-04-01    253
# 2019-05-01    210
# 2019-06-01     25
# 2019-07-01    289
# 2019-08-01    178
# 2019-09-01     17
# 2019-10-01    325
# 2019-11-01    140
# 2019-12-01     25
# Name: gvkey, dtype: int64

# %%
SP_500=SP_500.drop(columns=['companyname_y','transcriptid.1'])
SP_500 = SP_500.rename(columns={'companyname_x': 'companyname'})

# %%
SP_500.to_csv('SP500_2019.csv',index=False)

# %% [markdown]
# ### interact with Stata by using the API

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

df=pd.read_csv('SP500_2020.csv')  #read file

# %%
df.sample()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.sample()
#
# NameError: name 'df' is not defined

# %%
event=df[['permno','mostimportantdateutc']]
event.sample(5)
# Out:
#         permno mostimportantdateutc
# 82042    77129           2020-08-07
# 2283     11618           2020-10-13
# 45942    38762           2020-11-02
# 37761    26403           2020-08-04
# 100710   85072           2020-05-27

# %%
event=event.drop_duplicates()
event.head(5)
# Out:
#      permno mostimportantdateutc
# 0     10104           2020-03-12
# 31    10104           2020-06-16
# 55    10104           2020-09-10
# 82    10104           2020-12-10
# 112   10107           2020-01-29

# %%
event.to_csv('event.txt',sep=' ', index=False)

# %%
match=df[['permno','mostimportantdateutc','transcriptid']]
match.drop_duplicates()
# Out:
#         permno mostimportantdateutc  transcriptid
# 0        10104           2022-03-10     2522984.0
# 29       10104           2022-06-13     2588744.0
# 59       10104           2022-09-12     2645685.0
# 92       10104           2022-12-12     2708926.0
# 119      10107           2022-01-25     2477196.0
# ...        ...                  ...           ...
# 120744   93429           2022-11-04     2702934.0
# 120777   93436           2022-01-26     2478134.0
# 120873   93436           2022-04-20     2540576.0
# 120986   93436           2022-07-20     2601753.0
# 121099   93436           2022-10-19     2669494.0
#
# [1975 rows x 3 columns]

# %%
match=match.reset_index(drop=True)
match.drop_duplicates()
match.to_stata('match.dta')
